# %%
# Importacion del CSV a trabajar y las respectivas librerías.

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("SYB66_246_202310_Population Growth, Fertility and Mortality Indicators.csv")
df.head()
# Out:
#    Region/Country/Area                     Unnamed: 1  Year  \
# 0                    1  Total, all countries or areas  2010
# 1                    1  Total, all countries or areas  2010
# 2                    1  Total, all countries or areas  2010
# 3                    1  Total, all countries or areas  2010
# 4                    1  Total, all countries or areas  2010
#
#                                               Series Value Footnotes  \
# 0       Population annual rate of increase (percent)   1.3       NaN
# 1          Total fertility rate (children per women)   2.6       NaN
# 2  Infant mortality for both sexes (per 1,000 liv...  37.1       NaN
# 3  Maternal mortality ratio (deaths per 100,000 p...   254       NaN
# 4    Life expectancy at birth for both sexes (years)  70.1       NaN
#
#                                               Source
# 0  United Nations Population Division, New York, ...
# 1  United Nations Population Division, New York, ...
# ...

# %%
# Filtración por año 2020

datos_2020 = df['Year'] == 2020

df_2020 = df[datos_2020]
df_2020.head(50)
# Out:
#      Region/Country/Area                     Unnamed: 1  Year  \
# 14                     1  Total, all countries or areas  2020
# 15                     1  Total, all countries or areas  2020
# 16                     1  Total, all countries or areas  2020
# 17                     1  Total, all countries or areas  2020
# 18                     1  Total, all countries or areas  2020
# 19                     1  Total, all countries or areas  2020
# 20                     1  Total, all countries or areas  2020
# 41                     2                         Africa  2020
# 42                     2                         Africa  2020
# 43                     2                         Africa  2020
# 44                     2                         Africa  2020
# 45                     2                         Africa  2020
# 46                     2                         Africa  2020
# 47                     2                         Africa  2020
# ...

# %%
# Filtrado por filas solicitadas

df_filtrado = df_2020[df_2020['Series'].isin(['Infant mortality for both sexes (per 1,000 live births)', 'Life expectancy at birth for both sexes (years)'])]
df_filtrado.head(30)
# Out:
#      Region/Country/Area                     Unnamed: 1  Year  \
# 16                     1  Total, all countries or areas  2020
# 18                     1  Total, all countries or areas  2020
# 43                     2                         Africa  2020
# 45                     2                         Africa  2020
# 70                    15                Northern Africa  2020
# 72                    15                Northern Africa  2020
# 97                   202             Sub-Saharan Africa  2020
# 99                   202             Sub-Saharan Africa  2020
# 124                   14                 Eastern Africa  2020
# 126                   14                 Eastern Africa  2020
# 151                   17                  Middle Africa  2020
# 153                   17                  Middle Africa  2020
# 178                   18                Southern Africa  2020
# 180                   18                Southern Africa  2020
# ...

# %%
# Filtro final para elaboración gráfica

df_final = df_filtrado[['Region/Country/Area', 'Year', 'Series', 'Value']]
df_final.head()
# Out:
#     Region/Country/Area  Year  \
# 16                    1  2020
# 18                    1  2020
# 43                    2  2020
# 45                    2  2020
# 70                   15  2020
#
#                                                Series Value
# 16  Infant mortality for both sexes (per 1,000 liv...  28.3
# 18    Life expectancy at birth for both sexes (years)    72
# 43  Infant mortality for both sexes (per 1,000 liv...  46.4
# 45    Life expectancy at birth for both sexes (years)  62.2
# 70  Infant mortality for both sexes (per 1,000 liv...  22.6

# %%
# Gráfico tipo 'Swarm'

fix, ax = plt.subplots(figsize=(10, 6))
sns.swarmplot(data=df_final, x='Series', y='Value')
sns.set_style("darkgrid")
sns.despine(left=True, bottom=True)
ax.axes.yaxis.set_ticks([])
ax.set_xlabel('')
ax.set_ylabel('Rango')
plt.title('Gráfico Swarm')
plt.savefig('gráfico_swarm.jpg', dpi = 500)

# %%
# Gráfico tipo 'Violin'

fix, ax = plt.subplots(figsize=(10, 6))
sns.violinplot(data=df_final, x='Series', y='Value')
sns.set_style("darkgrid")
sns.despine(left=True, bottom=True)
ax.axes.yaxis.set_ticks([])
ax.set_xlabel('')
ax.set_ylabel('Rango')
plt.title('Gráfico Violin')
plt.savefig('Gráfico Violin.jpg', dpi = 500)

# %%
# Gráfico tipo 'Line'

fix, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(data=df_final, x='Series', y='Value')
ax.axes.yaxis.set_ticks([])
plt.title('Comparación expectativa de natalidad con mortalidad')
plt.savefig('gráfico_line.jpg', dpi = 500)

# %%
fix, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(data=df_final, x='Region/Country/Area', y='Value', hue='Series')
sns.set_style("darkgrid")
sns.despine(left=True, bottom=True)
ax.axes.yaxis.set_ticks([])
ax.set_xlabel('Regiones/Países')
ax.set_ylabel('Rango')
plt.title('Gráfico Lineplot')
plt.savefig('Gráfico Lineplot.jpg', dpi = 500)
