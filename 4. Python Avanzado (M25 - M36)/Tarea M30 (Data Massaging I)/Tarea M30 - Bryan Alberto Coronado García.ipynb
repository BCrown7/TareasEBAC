# %% [markdown]
# ## TAREA M30 - BRYAN ALBERTO CORONADO GARCÍA

# %% [markdown]
# ##### Importación de librerías y verificación de directorio

# %%
import pandas as pd
import os

# Verificación de directorio actual y actualización

cwd = os.getcwd()
os.chdir(r'C:/Users/thehe/Downloads')
cwd
# Out:
# 'C:\\Users\\thehe\\Downloads'

# %% [markdown]
# ##### Lectura del archivo con Pandas

# %%
# Uso de librería Pandas para leer un archivo (fifa_eda.csv)

df = pd.read_csv('fifa_eda.csv')

# %% [markdown]
# ##### Mostrar las primeras 20 filas del archivo, las últimas 5 y un sample de 10

# %%
# Las veinte primeras filas

df.head(20)
# Out:
#         ID               Name  Age Nationality  Overall  Potential  \
# 0   158023           L. Messi   31   Argentina       94         94
# 1    20801  Cristiano Ronaldo   33    Portugal       94         94
# 2   190871          Neymar Jr   26      Brazil       92         93
# 3   193080             De Gea   27       Spain       91         93
# 4   192985       K. De Bruyne   27     Belgium       91         92
# 5   183277          E. Hazard   27     Belgium       91         91
# 6   177003          L. Modrić   32     Croatia       91         91
# 7   176580          L. Suárez   31     Uruguay       91         91
# 8   155862       Sergio Ramos   32       Spain       91         91
# 9   200389           J. Oblak   25    Slovenia       90         93
# 10  188545     R. Lewandowski   29      Poland       90         90
# 11  182521           T. Kroos   28     Germany       90         90
# 12  182493           D. Godín   32     Uruguay       90         90
# ...

# %%
# Las cinco últimas filas

df.tail(5)
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                    Club  Value  Wage Preferred Foot  International Reputation  \
# 18202   Crewe Alexandra   60.0   1.0          Right                       1.0
# 18203    Trelleborgs FF   60.0   1.0          Right                       1.0
# 18204  Cambridge United   60.0   1.0          Right                       1.0
# 18205   Tranmere Rovers   60.0   1.0          Right                       1.0
# 18206   Tranmere Rovers   60.0   1.0          Right                       1.0
#
# ...

# %%
# Un sampleo aleatorio de diez filas

df.sample(10)
# Out:
#            ID          Name  Age       Nationality  Overall  Potential  \
# 1586   213000   S. van Beek   23       Netherlands       75         78
# 454    205988       L. Shaw   22           England       80         85
# 11681  245159    Juan Ibiza   22             Spain       64         73
# 12855  213959  E. Andersson   22            Sweden       63         71
# 10497  193931      T. Brown   27             Wales       65         65
# 16081  241552   J. Italiano   16         Australia       58         79
# 7129   205951       Rafinha   36            Brazil       68         68
# 14677  215820   L. Donnelly   22  Northern Ireland       60         71
# 5856   135743    Alex Geijo   36             Spain       69         69
# 15733  225756  G. Blackwood   21         Australia       59         65
#
#                     Club    Value  Wage Preferred Foot  \
# 1586           Feyenoord   7000.0  11.0          Right
# 454    Manchester United  16500.0  96.0           Left
# ...

# %% [markdown]
# ##### Generar data estadística con .describe() y además los tipos de datos del dataset

# %%
# Data estadística del DataFrame

df.describe()
# Out:
#                   ID           Age       Overall     Potential          Value  \
# count   18207.000000  18207.000000  18207.000000  18207.000000   17955.000000
# mean   214298.338606     25.122206     66.238699     71.307299    2444.530214
# std     29965.244204      4.669943      6.908930      6.136496    5626.715434
# min        16.000000     16.000000     46.000000     48.000000      10.000000
# 25%    200315.500000     21.000000     62.000000     67.000000     325.000000
# 50%    221759.000000     25.000000     66.000000     71.000000     700.000000
# 75%    236529.500000     28.000000     71.000000     75.000000    2100.000000
# max    246620.000000     45.000000     94.000000     95.000000  118500.000000
#
#                Wage  International Reputation   Skill Moves        Joined  \
# count  18207.000000              18159.000000  18159.000000  18207.000000
# mean       9.731312                  1.113222      2.361308   2016.420607
# ...

# %%
# Verificación de los tipos de dato de las columnas

df.dtypes
# Out:
# ID                            int64
# Name                         object
# Age                           int64
# Nationality                  object
# Overall                       int64
# Potential                     int64
# Club                         object
# Value                       float64
# Wage                        float64
# Preferred Foot               object
# International Reputation    float64
# Skill Moves                 float64
# Position                     object
# Joined                        int64
# Contract Valid Until         object
# Height                      float64
# Weight                      float64
# Release Clause              float64
# dtype: object

# %% [markdown]
# ##### Si es necesario, pasar a numéricas por lo menos 2 columnas que contengan números para incluirlas en .describe(). Aplicar las técnicas aprendidas.

# %%
# Se verificaron las columnas para conlcuir que la data numerica es correcta en sus tipos y no son necesarios cambios adicionales.
# Tampoco se encontraron datos nulos o faltantes

# %%
print(df.shape)
print(df.isna().count())
# Out:
# (18207, 18)
# ID                          18207
# Name                        18207
# Age                         18207
# Nationality                 18207
# Overall                     18207
# Potential                   18207
# Club                        18207
# Value                       18207
# Wage                        18207
# Preferred Foot              18207
# International Reputation    18207
# Skill Moves                 18207
# Position                    18207
# Joined                      18207
# Contract Valid Until        18207
# Height                      18207
# Weight                      18207
# Release Clause              18207
# dtype: int64

# %% [markdown]
# ##### Añadir una columna “Years Playing”, que calcule el año actual menos la columna “Joined”

# %%
df['Years Playing'] = 2025 - df['Joined']

df.sample(5)
# Out:
#            ID            Name  Age     Nationality  Overall  Potential  \
# 4494   200113    F. Jozefzoon   27     Netherlands       71         71
# 1214   171018    Mario Suárez   31           Spain       76         76
# 8562   241874     A. Blondell   24       Venezuela       67         74
# 10674  207546  Shim Dong Woon   28  Korea Republic       65         65
# 7330   225200      Kike Barja   21           Spain       68         75
#
#                          Club   Value  Wage Preferred Foot  \
# 4494             Derby County  2500.0  29.0          Right
# 1214      Guizhou Hengfeng FC  6500.0  16.0          Right
# 8562   Vancouver Whitecaps FC  1100.0   3.0          Right
# 10674        Sangju Sangmu FC   525.0   2.0           Left
# 7330               CA Osasuna  1300.0   3.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 4494                        1.0          3.0       RW    2018
# ...

# %% [markdown]
# ##### Buscar y mostrar a todos los jugadores de Mexico

# %%
df[['ID', 'Name', 'Nationality']].loc[df['Nationality'] == 'Mexico']
# Out:
#            ID          Name Nationality
# 306    171897   A. Guardado      Mexico
# 329    221992     H. Lozano      Mexico
# 371    193165     J. Corona      Mexico
# 397    169416       C. Vela      Mexico
# 406    156519    H. Herrera      Mexico
# ...       ...           ...         ...
# 17373  244828  R. Gutiérrez      Mexico
# 17614  239739      A. Ocejo      Mexico
# 18037  246089      C. Landa      Mexico
# 18068  240286     J. García      Mexico
# 18113  237045    R. Pasquel      Mexico
#
# [366 rows x 3 columns]

# %% [markdown]
# ##### Ordenar y mostrar los datos por la columna ReleaseClause (sueldo)

# %%
df[['Name', 'Release Clause']].sort_values(by = 'Release Clause', ascending=False)
# Out:
#                    Name  Release Clause
# 2             Neymar Jr        228100.0
# 0              L. Messi        226500.0
# 4          K. De Bruyne        196400.0
# 5             E. Hazard        172100.0
# 25            K. Mbappé        166100.0
# ...                 ...             ...
# 16204        C. Månsson            13.0
# 16249       B. Lekström            13.0
# 16565       K. Kitamoto            13.0
# 16628  K. Stamatopoulos            13.0
# 17209        Y. Nishibe            13.0
#
# [18207 rows x 2 columns]

# %% [markdown]
# ##### Generar un nuevo dataset que contenga el año (joined) y el número de jugadores (groupby)

# %%
df_joined = df.groupby(['Joined'])['ID'].count()

df_joined
# Out:
# Joined
# 1991       1
# 1998       3
# 1999       1
# 2000       2
# 2001       2
# 2002      10
# 2003      13
# 2004      12
# 2005      17
# 2006      18
# 2007      38
# 2008      53
# 2009      78
# 2010     131
# 2011     201
# 2012     340
# 2013     458
# 2014     818
# 2015    1336
# 2016    3799
# 2017    4307
# 2018    6569
# Name: ID, dtype: int64

# %% [markdown]
# ##### ❖Opcional❖: Generar un gráfico que contenga, por año, el número de jugadores

# %%
df_joined.plot()
# Out:
# <Axes: xlabel='Joined'>
